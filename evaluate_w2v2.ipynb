# %% [markdown]
# <a href="https://colab.research.google.com/github/machiobrian/Hugging_Face/blob/master/evaluate_w2v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
! pip install datasets
! pip install torchaudio
! pip install huggingface_hub
! pip install transformers
! pip install librosa
! pip install jiwer

# %%
# since we are looking forward to downloading the model, we use the read API access key
from huggingface_hub import notebook_login
notebook_login()
# Out:
# Token is valid.
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.huggingface/token
# Login successful

# %%
# load the model
from transformers import AutoModelForCTC, Wav2Vec2Processor

# %%
model = AutoModelForCTC.from_pretrained("ix502iv/wa2vec2-large-xls-r-colab_turkish")
processor = Wav2Vec2Processor.from_pretrained("ix502iv/wa2vec2-large-xls-r-colab_turkish")
# Out:
# Downloading:   0%|          | 0.00/2.06k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/214 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/291 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/429 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/96.0 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
from evaluate import load
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-553e4202048e> in <module>
# ----> 1 from evaluate import load
#
# ModuleNotFoundError: No module named 'evaluate'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
